# %%
print("Init..")
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Init..

# %%
# %%info
# Out:
# Current session configs: <tt>{'driverMemory': '1000M', 'executorCores': 2, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>4</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td></td></tr><tr><td>5</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td>✔</td></tr></table>

# %%
sc.parallelize(range(1000)).count()
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# 1000

# %%
import os
print(os.environ.get('SPARK_HOME', None))
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# /spark/spark-2.4.7-bin-hadoop2.7

# %%
# %%info
# Out:
# Current session configs: <tt>{'driverMemory': '1000M', 'executorCores': 2, 'kind': 'pyspark'}</tt><br>
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>4</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td></td></tr><tr><td>5</td><td>None</td><td>pyspark</td><td>idle</td><td></td><td></td><td>✔</td></tr></table>

# %%
# %%sql
# show tables
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# VBox(children=(HBox(), EncodingWidget(children=(VBox(children=(HTML(value='Encoding:'), Dropdown(description='…
# Output()

# %%
path = "/user/root/customers"
parquet_rdd = sc.newAPIHadoopFile(
    path,
    'org.apache.hadoop.mapreduce.lib.input.KeyValueTextInputFormat',
    'java.lang.String',
    'java.lang.String')
output = parquet_rdd.toDF().collect()
print(output[0])
#for k in output:
#    print(k)
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# Row(_1=u'1,Debra,Burks,null,debra.burks@yahoo.com,9273 Thorne Ave. ,Orchard Park,NY,14127', _2=u'')

# %%
df = sc.textFile(path)\
        .map(lambda line: (line.split(',')[0], line.split(',')[1], line.split(',')[2], line.split(',')[3], line.split(',')[4], line.split(',')[5], line.split(',')[6], line.split(',')[7], line.split(',')[8]))\
        .collect()
df
# Out:
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# [(u'1', u'Debra', u'Burks', u'null', u'debra.burks@yahoo.com', u'9273 Thorne Ave. ', u'Orchard Park', u'NY', u'14127'), (u'2', u'Kasha', u'Todd', u'null', u'kasha.todd@yahoo.com', u'910 Vine Street ', u'Campbell', u'CA', u'95008'), (u'3', u'Tameka', u'Fisher', u'null', u'tameka.fisher@aol.com', u'769C Honey Creek St. ', u'Redondo Beach', u'CA', u'90278'), (u'4', u'Daryl', u'Spence', u'null', u'daryl.spence@aol.com', u'988 Pearl Lane ', u'Uniondale', u'NY', u'11553'), (u'5', u'Charolette', u'Rice', u'(916) 381-6003', u'charolette.rice@msn.com', u'107 River Dr. ', u'Sacramento', u'CA', u'95820'), (u'6', u'Lyndsey', u'Bean', u'null', u'lyndsey.bean@hotmail.com', u'769 West Road ', u'Fairport', u'NY', u'14450'), (u'7', u'Latasha', u'Hays', u'(716) 986-3359', u'latasha.hays@hotmail.com', u'7014 Manor Station Rd. ', u'Buffalo', u'NY', u'14215'), (u'8', u'Jacquline', u'Duncan', u'null', u'jacquline.duncan@yahoo.com', u'15 Brown St. ', u'Jackson Heights', u'NY', u'11372'), (u'9', u'Genoveva', u'Baldwin', u'null', u'genoveva.baldwin@msn.com', u'8550 Spruce Drive ', u'Port Washington', u'NY', u'11050'), (u'10', u'Pamelia', u'Newman', u'null', u'pamelia.newman@gmail.com', u'476 Chestnut Ave. ', u'Monroe', u'NY', u'10950'), (u'11', u'Deshawn', u'Mendoza', u'null', u'deshawn.